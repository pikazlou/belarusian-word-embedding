# %% [markdown]
# Pretrained embeddings (cc.be.300.vec) downloaded from here: https://fasttext.cc/docs/en/crawl-vectors.html

# %%
from gensim.models.keyedvectors import load_word2vec_format

# %%
wv = load_word2vec_format('cc.be.300.vec')

# %%
wv.most_similar('воўк', topn=20)
# Out:
# [('-воўк', 0.6947126984596252),
#  ('335-348', 0.6508086323738098),
#  ('бог-воўк', 0.6280843615531921),
#  ('С.335-347.', 0.5851490497589111),
#  ('дзік', 0.540489673614502),
#  ('vlьkъ', 0.5338278412818909),
#  ('заяц', 0.5324456691741943),
#  ('барс', 0.5206909775733948),
#  ('воўка', 0.5115202069282532),
#  ('p.335-337.', 0.5028699040412903),
#  ('Сумчаты', 0.49996688961982727),
#  ('ваўкалак', 0.49866315722465515),
#  ('Стэпавы', 0.49767157435417175),
#  ('кот', 0.4959159195423126),
#  ('лютавоўк', 0.4833005368709564),
#  ('мядзведзь', 0.48065370321273804),
#  ('гепард', 0.4799012839794159),
#  ('ваўкi', 0.47961896657943726),
#  ('воўкадаў', 0.47588545083999634),
#  ('воўкі', 0.4756775498390198)]

# %%
wv.most_similar('беларусь', topn=20)
# Out:
# [('Ѕеларусь', 0.779540479183197),
#  ('Эўрабеларусь', 0.7684868574142456),
#  ('Літву-Беларусь', 0.7468840479850769),
#  ('.Беларусь', 0.7467460036277771),
#  ('БеларусьБеларусь', 0.7333645224571228),
#  ('еларусь', 0.7297027111053467),
#  ('ДР1П-104Беларусь', 0.7179664373397827),
#  ('ЕЗ-Беларусь', 0.7111337780952454),
#  ('ЭПр-004Беларусь', 0.7110381126403809),
#  ('РасеюБеларусь', 0.7109807133674622),
#  ('004Беларусь', 0.710799515247345),
#  ('006Беларусь', 0.7067102193832397),
#  ('ПольшчаСССРБеларусь', 0.7064422965049744),
#  ('маці-Беларусь', 0.706407368183136),
#  ('011Беларусь', 0.7061759233474731),
#  ('ЭР9Е-606Беларусь', 0.7055818438529968),
#  ('ЧС4Т-600Беларусь', 0.70490962266922),
#  ('нафтыБеларусь', 0.7044762372970581),
#  ('БКГ1-002Беларусь', 0.7035627365112305),
#  ('М62-1549Беларусь', 0.702379584312439)]

# %%
wv.most_similar('каханне', topn=20)
# Out:
# [('каханне.', 0.7619597911834717),
#  ('каханн', 0.7230203151702881),
#  ('сяброўства-каханне', 0.6946391463279724),
#  ('каханьне', 0.6873199343681335),
#  ('Некаханне', 0.6828450560569763),
#  ('каханніТВОРЧАЕ', 0.6792300343513489),
#  ('каханме', 0.6785784363746643),
#  ('каханнi', 0.6762933135032654),
#  ('каханні', 0.6669469475746155),
#  ('каханне-манію', 0.6606007814407349),
#  ('Каханне', 0.66053307056427),
#  ('аханне', 0.6484083533287048),
#  ('каханне.Першая', 0.640870213508606),
#  ('каханнем', 0.6395863890647888),
#  ('каханае', 0.6365221738815308),
#  ('каханцы', 0.6312995553016663),
#  ('каха', 0.6279096603393555),
#  ('каханне-апантанасць', 0.6171076893806458),
#  ('каханаю', 0.6078718304634094),
#  ('маханне', 0.6042895317077637)]
